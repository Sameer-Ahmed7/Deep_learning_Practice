# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.0.0'

# %%
mnist = tf.keras.datasets.mnist

# %%
(training_images,training_labels),(test_images,test_labels) = mnist.load_data()

# %%
training_images.shape
# Out:
# (60000, 28, 28)

# %%
len(training_labels)
# Out:
# 60000

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
import matplotlib.pyplot as plt
plt.imshow(training_images[0])

# %%
training_labels[0]
# Out:
# 5

# %%
plt.imshow(test_images[0])

# %%
test_labels[0]
# Out:
# 7

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(512,activation='relu',input_shape=(28*28,)))
model.add(tf.keras.layers.Dense(10,activation='softmax'))

# %%
model.compile(optimizer="rmsprop",loss='categorical_crossentropy',metrics=['accuracy'])

# %%
training_images=training_images.reshape((60000,28*28))
training_images = training_images.astype('float32')/255.0

test_images=test_images.reshape((10000,28*28))
test_images = test_images.astype('float32')/255.0

# %%
training_labels = tf.keras.utils.to_categorical(training_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

# %%
model.fit(training_images, training_labels, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 14s 227us/sample - loss: 0.2015 - accuracy: 0.9408
# Epoch 2/5
# 60000/60000 [==============================] - 13s 217us/sample - loss: 0.0901 - accuracy: 0.9740
# Epoch 3/5
# 60000/60000 [==============================] - 13s 221us/sample - loss: 0.0663 - accuracy: 0.9812
# Epoch 4/5
# 60000/60000 [==============================] - 13s 221us/sample - loss: 0.0504 - accuracy: 0.9858
# Epoch 5/5
# 60000/60000 [==============================] - 14s 235us/sample - loss: 0.0426 - accuracy: 0.9886

# %%
test_loss,test_acc = model.evaluate(test_images,test_labels)
print('test ACC : ',test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# test ACC :  0.9805
